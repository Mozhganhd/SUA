# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import burr12
from scipy.optimize import minimize
import os
np.random.seed(42)


def load_and_clean_data(filepath: str):
    xls = pd.ExcelFile(filepath)
    product_df = xls.parse("Demand")
    dist_df = xls.parse("Demand_Variance")
    product_df.index = product_df.iloc[:, 0]
    product_df = product_df.drop(columns=product_df.columns[0])
    product_df = product_df.T.reset_index(drop=True)
    product_df['ProductID'] = [f'P{i}' for i in range(len(product_df))]
    product_df['Demand'] = pd.to_numeric(product_df['Demand'], errors='coerce')
    product_df['Variance group'] = pd.to_numeric(product_df['Variance group'], downcast='integer', errors='coerce')
    product_df['Margin'] = pd.to_numeric(product_df['Margin'], errors='coerce')
    product_df['COGS'] = pd.to_numeric(product_df['COGS'], errors='coerce')
    product_df['Substitutability group'] = pd.to_numeric(product_df['Substitutability group'], downcast='integer', errors='coerce')
    product_df['Capacity'] = product_df['Capacity'].astype(str).str.rstrip('%')
    product_df['Capacity'] = pd.to_numeric(product_df['Capacity'], errors='coerce')
    product_df['Capacity'] = product_df['Capacity'].apply(lambda x: x if pd.notna(x) else 1.0)
    dist_df.columns = ['DemandVarGroup', 'distribution', 'c', 'd', 'loc', 'scale']
    product_df = product_df.rename(columns={'Variance group': 'DemandVarGroup'})
    product_df = product_df.merge(dist_df.drop(columns='distribution'), on='DemandVarGroup', how='left')
    return product_df

def simulate_demand(product_df: pd.DataFrame, n_samples: int = 500) -> np.ndarray:
    simulated_demand = []
    for _, row in product_df.iterrows():
        dist = burr12(row['c'], row['d'], loc=row['loc'], scale=row['scale'])
        simulated = row['Demand'] * dist.rvs(size=n_samples)
        simulated_demand.append(simulated)
    return np.array(simulated_demand)

def define_objective(demand, margin, cogs, simulated_demand, max_surplus):
    def objective(surplus):
        surplus = np.clip(surplus, 0, max_surplus)
        sales = np.minimum(demand[:, None] + surplus[:, None], simulated_demand)
        revenue = sales * margin[:, None]
        cost = surplus[:, None] * cogs[:, None]
        total_profit = revenue.sum(axis=0) - cost.sum(axis=0)

        if np.any(np.isnan(total_profit)) or np.any(np.isinf(total_profit)):
            return 1e10
        return -np.mean(total_profit)
    return objective

def run_optimization_with_group_constraints(product_df: pd.DataFrame, simulated_demand: np.ndarray, macro_cap: float):
    demand = product_df['Demand'].values
    margin = product_df['Margin'].values
    cogs = product_df['COGS'].values
    capacity = product_df['Capacity'].values
    max_surplus = capacity * demand
    total_demand = demand.sum()
    n_products = len(demand)

    objective_fn = define_objective(demand, margin, cogs, simulated_demand, max_surplus)

    expected_actual = simulated_demand.mean(axis=1)
    overflow = np.maximum(expected_actual - demand, 0)
    sub_groups = product_df.groupby('Substitutability group').groups

    group_constraints = []
    for group_id, indices in sub_groups.items():
        valid_idx = [i for i in indices if max_surplus[i] > 0]
        if len(valid_idx) > 1:
            idx = list(valid_idx)
            required = overflow[idx].sum() * ss
            group_constraints.append({
                'type': 'ineq',
                'fun': lambda x, idx=idx, req=required: np.sum(x[idx]) - req
            })

    constraints = [{'type': 'ineq', 'fun': lambda x: macro_cap * total_demand - np.sum(x)}]  + group_constraints
    bounds = [(0, ms if np.isfinite(ms) else None) for ms in max_surplus]
    x0 = 0.2 * max_surplus
    # x0 = np.zeros(n_products)
    x0[max_surplus == 0] = 0


    result = minimize(
        objective_fn,
        x0,
        method=method,
        bounds=bounds,
        constraints=constraints,
        options={'maxiter': 1000, 'disp': True}
    )

    return result, max_surplus, overflow, sub_groups

def save_results_and_visualize(product_df, result, max_surplus, simulated_demand, overflow, sub_groups, output_dir="SLSQP_SoftConstraints"):
    os.makedirs(output_dir, exist_ok=True)

    demand = product_df['Demand'].values
    margin = product_df['Margin'].values
    cogs = product_df['COGS'].values

    product_df['OptimalSurplus'] = result.x
    product_df['MaxSurplus'] = max_surplus

    output_csv = os.path.join(output_dir, "optimal_surplus_output.csv")
    product_df[['ProductID', 'Demand', 'Margin', 'COGS', 'Capacity', 'OptimalSurplus']].to_csv(output_csv, index=False)

    sales = np.minimum(demand[:, None] + result.x[:, None], simulated_demand)
    revenue = sales * margin[:, None]
    cost = result.x[:, None] * cogs[:, None]
    profit = revenue.sum(axis=0) - cost.sum(axis=0)

    pd.DataFrame({'Profit': profit}).to_csv(os.path.join(output_dir, "profit.csv"), index=False)

    group_data = []
    for group_id, indices in sub_groups.items():
        idx = list(indices)
        group_surplus = result.x[idx].sum()
        group_need = overflow[idx].sum()
        gap = group_need - group_surplus
        group_data.append({'Group': group_id, 'Surplus': group_surplus, 'Need': group_need, 'Gap': gap})
        print(f"Group {group_id}: Surplus = {group_surplus:.2f}, Needed = {group_need:.2f}, Gap = {gap:.2f}")

    pd.DataFrame(group_data).to_csv(os.path.join(output_dir, "group_summary.csv"), index=False)

    print(f"\nOptimization finished: {'Success' if result.success else 'Not converged'}")
    print("Message:", result.message)

    # === Plots ===
    plt.figure(figsize=(14, 6))
    plt.bar(product_df['ProductID'], result.x, color='royalblue')
    # plt.xticks(rotation=90)
    plt.xticks(ticks=np.arange(0, len(product_df), 10), labels=product_df['ProductID'][::10], rotation=45)
    plt.ylabel('Surplus Units')
    plt.title('Optimal Surplus per Product')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "surplus_per_product.png"))
    plt.close()

    plt.hist(profit, bins=30, color='green', edgecolor='black')
    plt.title('Histogram of Simulated Total Profits')
    plt.xlabel('Total Profit')
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "profit_distribution.png"))
    plt.close()

    print("\nMean Profit:", np.mean(profit))
    print("Std Dev Profit:", np.std(profit))
    print("Saved all outputs to:", output_dir)


def main():
    filepath = r"C:\Users\hadad\OneDrive - Iowa State University\personal\Corteva\Input_SUA.xlsx"
    product_df = load_and_clean_data(filepath)
    # product_df = product_df.iloc[:100]
    simulated_demand = simulate_demand(product_df, n_samples)
    result, max_surplus, overflow, sub_groups = run_optimization_with_group_constraints(product_df, simulated_demand, macro_cap)
    save_results_and_visualize(product_df, result, max_surplus, simulated_demand, overflow, sub_groups)

if __name__ == "__main__":
    method = 'SLSQP'
    macro_cap = 0.4
    n_samples = 100
    ss = 0.01
    print("method:", method)
    print("macro_cap:", macro_cap)
    print("n_samples:", n_samples)
    print("ss:", ss)
    main()
    
# Mean Expected Profit: $3.63 Billion

# Standard Deviation: $67 Million
# (From 100 Monte Carlo simulations)
# Out:
# method: SLSQP
# macro_cap: 0.4
# n_samples: 100
# ss: 0.01
# c:\Users\hadad\anaconda3\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3634963656.6205516
#             Iterations: 521
#             Function evaluations: 237272
#             Gradient evaluations: 519
# Group 0: Surplus = 32762.01, Needed = 30340.49, Gap = -2421.52
# Group 1: Surplus = 13880.47, Needed = 6711.67, Gap = -7168.80
# Group 2: Surplus = 34380.88, Needed = 53355.56, Gap = 18974.68
# Group 3: Surplus = 36436.32, Needed = 6863.42, Gap = -29572.90
# Group 4: Surplus = 10481.59, Needed = 2279.92, Gap = -8201.67
# Group 5: Surplus = 1940.41, Needed = 0.00, Gap = -1940.41
# Group 6: Surplus = 13232.69, Needed = 22007.98, Gap = 8775.29
# Group 7: Surplus = 15813.34, Needed = 5641.90, Gap = -10171.44
# Group 8: Surplus = 22064.16, Needed = 2231.39, Gap = -19832.77
# Group 9: Surplus = 75748.75, Needed = 72482.62, Gap = -3266.13
# Group 10: Surplus = 3824.98, Needed = 4298.70, Gap = 473.72
# Group 11: Surplus = 11910.59, Needed = 15495.41, Gap = 3584.82
# Group 12: Surplus = 9453.74, Needed = 14400.10, Gap = 4946.36
# Group 13: Surplus = 12943.80, Needed = 13606.79, Gap = 662.99
# Group 14: Surplus = 11347.78, Needed = 16559.85, Gap = 5212.06
# Group 15: Surplus = 12928.83, Needed = 35175.23, Gap = 22246.40
# Group 16: Surplus = 2992.45, Needed = 5588.41, Gap = 2595.96
# Group 17: Surplus = 30305.25, Needed = 17747.29, Gap = -12557.96
# Group 18: Surplus = 88980.95, Needed = 61313.49, Gap = -27667.45
# Group 19: Surplus = 30891.24, Needed = 62354.57, Gap = 31463.33
# Group 20: Surplus = 4808.81, Needed = 17187.62, Gap = 12378.81
# Group 21: Surplus = 123576.28, Needed = 73657.53, Gap = -49918.75
# Group 22: Surplus = 9735.39, Needed = 14031.71, Gap = 4296.33
# Group 23: Surplus = 33679.22, Needed = 22658.50, Gap = -11020.72
# Group 24: Surplus = 0.87, Needed = 576.35, Gap = 575.48
# Group 25: Surplus = 8.53, Needed = 42.44, Gap = 33.91
# Group 26: Surplus = 27075.63, Needed = 57102.80, Gap = 30027.16
# Group 27: Surplus = 12.73, Needed = 0.00, Gap = -12.73
# Group 28: Surplus = 52616.25, Needed = 50136.71, Gap = -2479.54
# Group 29: Surplus = 68.35, Needed = 8192.97, Gap = 8124.63
# Group 30: Surplus = 13619.10, Needed = 62605.43, Gap = 48986.32
# Group 31: Surplus = 24562.16, Needed = 46223.18, Gap = 21661.01
# Group 32: Surplus = 42001.86, Needed = 57646.41, Gap = 15644.55
# Group 33: Surplus = 112.74, Needed = 1065.11, Gap = 952.37
# Group 34: Surplus = 4911.63, Needed = 2092.00, Gap = -2819.63
# Group 35: Surplus = 29480.00, Needed = 4020.24, Gap = -25459.76
# Group 36: Surplus = 11378.28, Needed = 4553.78, Gap = -6824.49
# Group 37: Surplus = 8424.30, Needed = 1822.66, Gap = -6601.64
# Group 38: Surplus = 24.30, Needed = 50.70, Gap = 26.39
# Group 39: Surplus = 2773.73, Needed = 11606.37, Gap = 8832.64
# Group 40: Surplus = 12.37, Needed = 600.30, Gap = 587.93
# Group 41: Surplus = 80707.03, Needed = 59312.71, Gap = -21394.32
# Group 42: Surplus = 28.81, Needed = 0.00, Gap = -28.81
# Group 43: Surplus = 0.00, Needed = 2491.14, Gap = 2491.14
# Group 44: Surplus = 25094.78, Needed = 8421.07, Gap = -16673.70
# Group 45: Surplus = 102850.72, Needed = 74654.40, Gap = -28196.32
# Group 46: Surplus = 7.21, Needed = 0.00, Gap = -7.21
# Group 47: Surplus = 193.70, Needed = 574.30, Gap = 380.60
# Group 48: Surplus = 16002.48, Needed = 23834.73, Gap = 7832.24
# Group 49: Surplus = 35429.15, Needed = 82576.98, Gap = 47147.83
# Group 50: Surplus = 113310.26, Needed = 66640.34, Gap = -46669.93
# Group 51: Surplus = 9975.89, Needed = 18873.76, Gap = 8897.87
# Group 52: Surplus = 11754.00, Needed = 46713.89, Gap = 34959.89
# Group 53: Surplus = 129481.52, Needed = 115870.18, Gap = -13611.34
# Group 54: Surplus = 6988.27, Needed = 11251.82, Gap = 4263.55
# Group 55: Surplus = 37336.78, Needed = 53272.35, Gap = 15935.57
# Group 56: Surplus = 7081.80, Needed = 33631.56, Gap = 26549.76
# Group 57: Surplus = 65881.87, Needed = 39811.07, Gap = -26070.80
# Group 58: Surplus = 102750.12, Needed = 72635.55, Gap = -30114.57
# Group 59: Surplus = 17447.22, Needed = 22585.05, Gap = 5137.83
# Group 60: Surplus = 19844.44, Needed = 32232.80, Gap = 12388.36
# Group 61: Surplus = 74858.72, Needed = 67828.57, Gap = -7030.15
# Group 62: Surplus = 4425.47, Needed = 19189.50, Gap = 14764.03
# Group 63: Surplus = 24035.97, Needed = 23264.62, Gap = -771.35
# Group 64: Surplus = 5970.16, Needed = 21838.99, Gap = 15868.84
# Group 65: Surplus = 24001.65, Needed = 15441.16, Gap = -8560.49
# Group 66: Surplus = 79674.45, Needed = 25378.90, Gap = -54295.55
# Group 67: Surplus = 0.04, Needed = 31885.36, Gap = 31885.32
# Group 68: Surplus = 7444.58, Needed = 0.00, Gap = -7444.58
# Group 69: Surplus = 0.03, Needed = 10390.57, Gap = 10390.54
# Group 70: Surplus = 4041.30, Needed = 2871.15, Gap = -1170.14
# Group 71: Surplus = 12318.82, Needed = 2392.76, Gap = -9926.05
# Group 72: Surplus = 0.00, Needed = 0.00, Gap = -0.00
# Group 73: Surplus = 20747.51, Needed = 6371.89, Gap = -14375.61
# Group 74: Surplus = 3918.75, Needed = 21160.44, Gap = 17241.69
# Group 75: Surplus = 13.52, Needed = 0.00, Gap = -13.52
# Group 76: Surplus = 4189.23, Needed = 3310.47, Gap = -878.76
# Group 77: Surplus = 14899.13, Needed = 0.00, Gap = -14899.13
# Group 78: Surplus = 14417.11, Needed = 65186.53, Gap = 50769.42
# Group 79: Surplus = 6165.69, Needed = 8403.65, Gap = 2237.96
# Group 80: Surplus = 29965.82, Needed = 50824.22, Gap = 20858.41
# Group 81: Surplus = 35.35, Needed = 1420.20, Gap = 1384.85
# Group 82: Surplus = 116665.91, Needed = 52613.86, Gap = -64052.05
# Group 83: Surplus = 12159.53, Needed = 3750.66, Gap = -8408.86
# Group 84: Surplus = 8452.75, Needed = 104.83, Gap = -8347.92
# Group 85: Surplus = 86889.71, Needed = 39420.57, Gap = -47469.14
# Group 86: Surplus = 24413.20, Needed = 18203.67, Gap = -6209.53
# Group 87: Surplus = 29222.89, Needed = 54364.35, Gap = 25141.46
# Group 88: Surplus = 0.00, Needed = 0.00, Gap = 0.00
# Group 89: Surplus = 69230.08, Needed = 22302.06, Gap = -46928.02
# Group 90: Surplus = 13.28, Needed = 0.00, Gap = -13.28
# Group 91: Surplus = 7906.50, Needed = 35369.19, Gap = 27462.69
# Group 92: Surplus = 42.08, Needed = 3068.71, Gap = 3026.63
# Group 93: Surplus = 47094.60, Needed = 78515.90, Gap = 31421.30
# Group 94: Surplus = 0.53, Needed = 0.00, Gap = -0.53
# Group 95: Surplus = 6.66, Needed = 0.00, Gap = -6.66
# Group 96: Surplus = 10011.65, Needed = 2391.40, Gap = -7620.24
# Group 97: Surplus = 7.32, Needed = 1824.49, Gap = 1817.17
# Group 98: Surplus = 39544.85, Needed = 51399.57, Gap = 11854.72
# Group 99: Surplus = 4734.03, Needed = 1988.76, Gap = -2745.27
# Group 100: Surplus = 34313.89, Needed = 15378.69, Gap = -18935.20
# Group 101: Surplus = 32.74, Needed = 6820.79, Gap = 6788.06
# Group 102: Surplus = 4456.38, Needed = 0.00, Gap = -4456.38
# Group 103: Surplus = 25963.25, Needed = 7547.95, Gap = -18415.30
# Group 104: Surplus = 14848.22, Needed = 7499.35, Gap = -7348.87
# Group 105: Surplus = 0.31, Needed = 0.00, Gap = -0.31
# Group 106: Surplus = 278.18, Needed = 9712.96, Gap = 9434.78
# Group 107: Surplus = 12024.60, Needed = 55339.35, Gap = 43314.75
# Group 108: Surplus = 18760.49, Needed = 10431.58, Gap = -8328.91
# Group 109: Surplus = 505.06, Needed = 16377.29, Gap = 15872.23
# Group 110: Surplus = 4530.39, Needed = 1732.82, Gap = -2797.56
# Group 111: Surplus = 46296.06, Needed = 47933.52, Gap = 1637.47
# Group 112: Surplus = 5341.68, Needed = 22152.45, Gap = 16810.77
# Group 113: Surplus = 5710.18, Needed = 0.00, Gap = -5710.18
# Group 114: Surplus = 6200.64, Needed = 1223.47, Gap = -4977.17
# Group 115: Surplus = 0.76, Needed = 0.00, Gap = -0.76
# Group 116: Surplus = 10970.61, Needed = 17698.10, Gap = 6727.49
# Group 117: Surplus = 2836.65, Needed = 0.00, Gap = -2836.65
# Group 118: Surplus = 15459.79, Needed = 54818.64, Gap = 39358.85
# Group 119: Surplus = 2.23, Needed = 0.00, Gap = -2.23
# Group 120: Surplus = 8443.68, Needed = 13695.92, Gap = 5252.24
# Group 121: Surplus = 23839.70, Needed = 11634.42, Gap = -12205.28
# Group 122: Surplus = 94029.27, Needed = 62575.01, Gap = -31454.26
# Group 123: Surplus = 20164.16, Needed = 15753.90, Gap = -4410.26
# Group 124: Surplus = 10469.22, Needed = 25008.71, Gap = 14539.49
# Group 125: Surplus = 11476.50, Needed = 27410.11, Gap = 15933.61
# Group 126: Surplus = 7605.06, Needed = 32261.03, Gap = 24655.98
# Group 127: Surplus = 10631.49, Needed = 2876.48, Gap = -7755.01
# Group 128: Surplus = 37689.59, Needed = 100721.70, Gap = 63032.11
# Group 129: Surplus = 6253.72, Needed = 1192.28, Gap = -5061.44
# Group 130: Surplus = 19698.09, Needed = 6952.41, Gap = -12745.68
# Group 131: Surplus = 281.19, Needed = 10105.21, Gap = 9824.03
# Group 132: Surplus = 41712.97, Needed = 9364.53, Gap = -32348.44
# Group 133: Surplus = 66363.75, Needed = 117791.85, Gap = 51428.10
# Group 134: Surplus = 6056.55, Needed = 9633.08, Gap = 3576.53
# Group 135: Surplus = 0.00, Needed = 3926.88, Gap = 3926.88
# Group 136: Surplus = 2246.78, Needed = 3229.94, Gap = 983.16
# Group 137: Surplus = 0.37, Needed = 0.00, Gap = -0.37
# Group 138: Surplus = 8330.81, Needed = 18615.56, Gap = 10284.74
# Group 139: Surplus = 1957.43, Needed = 0.00, Gap = -1957.43
# Group 140: Surplus = 12360.44, Needed = 143.16, Gap = -12217.28
# Group 141: Surplus = 8517.31, Needed = 31820.45, Gap = 23303.14
# Group 142: Surplus = 11788.35, Needed = 56498.45, Gap = 44710.10
# Group 143: Surplus = 2.10, Needed = 19988.38, Gap = 19986.29
# Group 144: Surplus = 37805.85, Needed = 28711.63, Gap = -9094.23
# Group 145: Surplus = 81432.90, Needed = 61092.34, Gap = -20340.56
# Group 146: Surplus = 81102.26, Needed = 78896.19, Gap = -2206.07
# Group 147: Surplus = 11566.63, Needed = 70155.71, Gap = 58589.08
# Group 148: Surplus = 4312.23, Needed = 17476.67, Gap = 13164.44
# Group 149: Surplus = 7099.78, Needed = 3878.09, Gap = -3221.69
# Group 150: Surplus = 850.09, Needed = 3460.42, Gap = 2610.33
# Group 151: Surplus = 2040.07, Needed = 4016.74, Gap = 1976.67
# Group 152: Surplus = 233822.62, Needed = 295749.17, Gap = 61926.55
# Group 153: Surplus = 9.46, Needed = 0.00, Gap = -9.46
# Group 154: Surplus = 661.68, Needed = 19512.04, Gap = 18850.36
# Group 155: Surplus = 16655.14, Needed = 24536.14, Gap = 7881.00
# Group 156: Surplus = 4024.94, Needed = 9952.54, Gap = 5927.60
# Group 157: Surplus = 66155.99, Needed = 54078.85, Gap = -12077.14
# Group 158: Surplus = 11169.89, Needed = 1439.85, Gap = -9730.03
# Group 159: Surplus = 83615.52, Needed = 147455.77, Gap = 63840.24
# Group 160: Surplus = 31497.37, Needed = 19174.80, Gap = -12322.56
# Group 161: Surplus = 24123.87, Needed = 0.00, Gap = -24123.87
# Group 162: Surplus = 15555.37, Needed = 30850.27, Gap = 15294.90
# Group 163: Surplus = 5316.21, Needed = 8263.45, Gap = 2947.24
# Group 164: Surplus = 17332.59, Needed = 9493.65, Gap = -7838.94
# Group 165: Surplus = 9561.24, Needed = 69423.14, Gap = 59861.90
# Group 166: Surplus = 9469.79, Needed = 5279.52, Gap = -4190.27
# Group 167: Surplus = 24320.42, Needed = 75378.83, Gap = 51058.41
# Group 168: Surplus = 46407.29, Needed = 29974.77, Gap = -16432.53
# Group 169: Surplus = 10396.41, Needed = 5682.39, Gap = -4714.01
# Group 170: Surplus = 69980.14, Needed = 45334.84, Gap = -24645.30
# Group 171: Surplus = 6716.40, Needed = 2840.12, Gap = -3876.28
# Group 172: Surplus = 11941.10, Needed = 58065.09, Gap = 46123.99
# Group 173: Surplus = 6766.01, Needed = 35340.33, Gap = 28574.33
# Group 174: Surplus = 17623.14, Needed = 17692.02, Gap = 68.89
# Group 175: Surplus = 0.00, Needed = 20110.94, Gap = 20110.94
# Group 176: Surplus = 14648.05, Needed = 41258.74, Gap = 26610.68
# Group 177: Surplus = 16238.43, Needed = 15333.75, Gap = -904.68
# Group 178: Surplus = 1764.87, Needed = 0.00, Gap = -1764.87
# Group 179: Surplus = 124076.69, Needed = 74347.09, Gap = -49729.61
# Group 180: Surplus = 342.12, Needed = 923.58, Gap = 581.45
# Group 181: Surplus = 15109.70, Needed = 504.25, Gap = -14605.45
# Group 182: Surplus = 92523.64, Needed = 61521.36, Gap = -31002.28
# Group 183: Surplus = 0.00, Needed = 3250.83, Gap = 3250.83
# Group 184: Surplus = 9728.60, Needed = 0.00, Gap = -9728.60
# Group 185: Surplus = 27450.80, Needed = 61488.65, Gap = 34037.85
# Group 186: Surplus = 0.02, Needed = 0.00, Gap = -0.02
# Group 187: Surplus = 2.15, Needed = 0.00, Gap = -2.15
# Group 188: Surplus = 6633.60, Needed = 11293.19, Gap = 4659.59
# Group 189: Surplus = 0.00, Needed = 0.00, Gap = 0.00
# Group 190: Surplus = 10739.91, Needed = 7916.81, Gap = -2823.10
# Group 191: Surplus = 9898.39, Needed = 6351.19, Gap = -3547.20
# Group 192: Surplus = 487.42, Needed = 1889.63, Gap = 1402.21
# Group 193: Surplus = 1399.92, Needed = 9327.70, Gap = 7927.78
# Group 194: Surplus = 10317.89, Needed = 5354.81, Gap = -4963.09
# Group 195: Surplus = 41329.17, Needed = 47145.34, Gap = 5816.17
# Group 196: Surplus = 29048.23, Needed = 65731.76, Gap = 36683.53
# Group 197: Surplus = 37222.90, Needed = 12570.71, Gap = -24652.19
#
# Optimization finished: Success
# Message: Optimization terminated successfully
#
# Mean Profit: 3634963656.6205516
# Std Dev Profit: 67787821.80168217
# Saved all outputs to: SLSQP_SoftConstraints

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import burr12
from scipy.optimize import minimize
import os
np.random.seed(42)


def load_and_clean_data(filepath: str):
    xls = pd.ExcelFile(filepath)
    product_df = xls.parse("Demand")
    dist_df = xls.parse("Demand_Variance")
    product_df.index = product_df.iloc[:, 0]
    product_df = product_df.drop(columns=product_df.columns[0])
    product_df = product_df.T.reset_index(drop=True)
    product_df['ProductID'] = [f'P{i}' for i in range(len(product_df))]
    product_df['Demand'] = pd.to_numeric(product_df['Demand'], errors='coerce')
    product_df['Variance group'] = pd.to_numeric(product_df['Variance group'], downcast='integer', errors='coerce')
    product_df['Margin'] = pd.to_numeric(product_df['Margin'], errors='coerce')
    product_df['COGS'] = pd.to_numeric(product_df['COGS'], errors='coerce')
    product_df['Substitutability group'] = pd.to_numeric(product_df['Substitutability group'], downcast='integer', errors='coerce')
    product_df['Capacity'] = product_df['Capacity'].astype(str).str.rstrip('%')
    product_df['Capacity'] = pd.to_numeric(product_df['Capacity'], errors='coerce')
    product_df['Capacity'] = product_df['Capacity'].apply(lambda x: x if pd.notna(x) else 1.0)
    dist_df.columns = ['DemandVarGroup', 'distribution', 'c', 'd', 'loc', 'scale']
    product_df = product_df.rename(columns={'Variance group': 'DemandVarGroup'})
    product_df = product_df.merge(dist_df.drop(columns='distribution'), on='DemandVarGroup', how='left')
    return product_df

def simulate_demand(product_df: pd.DataFrame, n_samples: int = 500) -> np.ndarray:
    simulated_demand = []
    for _, row in product_df.iterrows():
        dist = burr12(row['c'], row['d'], loc=row['loc'], scale=row['scale'])
        simulated = row['Demand'] * dist.rvs(size=n_samples)
        simulated_demand.append(simulated)
    return np.array(simulated_demand)

def define_objective(demand, margin, cogs, simulated_demand, max_surplus):
    def objective(surplus):
        surplus = np.clip(surplus, 0, max_surplus)
        sales = np.minimum(demand[:, None] + surplus[:, None], simulated_demand)
        revenue = sales * margin[:, None]
        cost = surplus[:, None] * cogs[:, None]
        total_profit = revenue.sum(axis=0) - cost.sum(axis=0)

        if np.any(np.isnan(total_profit)) or np.any(np.isinf(total_profit)):
            return 1e10
        return -np.mean(total_profit)
    return objective

def run_optimization_with_group_constraints(product_df: pd.DataFrame, simulated_demand: np.ndarray, macro_cap: float):
    demand = product_df['Demand'].values
    margin = product_df['Margin'].values
    cogs = product_df['COGS'].values
    capacity = product_df['Capacity'].values
    max_surplus = capacity * demand
    total_demand = demand.sum()
    n_products = len(demand)

    objective_fn = define_objective(demand, margin, cogs, simulated_demand, max_surplus)

    expected_actual = simulated_demand.mean(axis=1)
    overflow = np.maximum(expected_actual - demand, 0)
    sub_groups = product_df.groupby('Substitutability group').groups

    group_constraints = []
    for group_id, indices in sub_groups.items():
        valid_idx = [i for i in indices if max_surplus[i] > 0]
        if len(valid_idx) > 1:
            idx = list(valid_idx)
            required = overflow[idx].sum() * ss
            group_constraints.append({
                'type': 'ineq',
                'fun': lambda x, idx=idx, req=required: np.sum(x[idx]) - req
            })

    constraints = [{'type': 'ineq', 'fun': lambda x: macro_cap * total_demand - np.sum(x)}]  + group_constraints
    bounds = [(0, ms if np.isfinite(ms) else None) for ms in max_surplus]
    x0 = 0.2 * max_surplus
    # x0 = np.zeros(n_products)
    x0[max_surplus == 0] = 0


    result = minimize(
        objective_fn,
        x0,
        method=method,
        bounds=bounds,
        constraints=constraints,
        options={'maxiter': 1000, 'disp': True}
    )

    return result, max_surplus, overflow, sub_groups

def save_results_and_visualize(product_df, result, max_surplus, simulated_demand, overflow, sub_groups, output_dir=f"SLSQP_SoftConstraints_gc{ss}"):
    os.makedirs(output_dir, exist_ok=True)

    demand = product_df['Demand'].values
    margin = product_df['Margin'].values
    cogs = product_df['COGS'].values

    product_df['OptimalSurplus'] = result.x
    product_df['MaxSurplus'] = max_surplus

    output_csv = os.path.join(output_dir, "optimal_surplus_output.csv")
    product_df[['ProductID', 'Demand', 'Margin', 'COGS', 'Capacity', 'OptimalSurplus']].to_csv(output_csv, index=False)

    sales = np.minimum(demand[:, None] + result.x[:, None], simulated_demand)
    revenue = sales * margin[:, None]
    cost = result.x[:, None] * cogs[:, None]
    profit = revenue.sum(axis=0) - cost.sum(axis=0)

    pd.DataFrame({'Profit': profit}).to_csv(os.path.join(output_dir, "profit.csv"), index=False)

    group_data = []
    for group_id, indices in sub_groups.items():
        idx = list(indices)
        group_surplus = result.x[idx].sum()
        group_need = overflow[idx].sum()
        gap = group_need - group_surplus
        group_data.append({'Group': group_id, 'Surplus': group_surplus, 'Need': group_need, 'Gap': gap})
        print(f"Group {group_id}: Surplus = {group_surplus:.2f}, Needed = {group_need:.2f}, Gap = {gap:.2f}")

    pd.DataFrame(group_data).to_csv(os.path.join(output_dir, "group_summary.csv"), index=False)

    print(f"\nOptimization finished: {'Success' if result.success else 'Not converged'}")
    print("Message:", result.message)

    # === Plots ===
    plt.figure(figsize=(14, 6))
    plt.bar(product_df['ProductID'], result.x, color='royalblue')
    # plt.xticks(rotation=90)
    plt.xticks(ticks=np.arange(0, len(product_df), 10), labels=product_df['ProductID'][::10], rotation=45)
    plt.ylabel('Surplus Units')
    plt.title('Optimal Surplus per Product')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "surplus_per_product.png"))
    plt.close()

    plt.hist(profit, bins=30, color='green', edgecolor='black')
    plt.title('Histogram of Simulated Total Profits')
    plt.xlabel('Total Profit')
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, "profit_distribution.png"))
    plt.close()

    print("\nMean Profit:", np.mean(profit))
    print("Std Dev Profit:", np.std(profit))
    print("Saved all outputs to:", output_dir)


def main():
    filepath = r"C:\Users\hadad\OneDrive - Iowa State University\personal\Corteva\Input_SUA.xlsx"
    product_df = load_and_clean_data(filepath)
    # product_df = product_df.iloc[:100]
    simulated_demand = simulate_demand(product_df, n_samples)
    result, max_surplus, overflow, sub_groups = run_optimization_with_group_constraints(product_df, simulated_demand, macro_cap)
    save_results_and_visualize(product_df, result, max_surplus, simulated_demand, overflow, sub_groups)

if __name__ == "__main__":
    method = 'SLSQP'
    macro_cap = 0.4
    n_samples = 100
    ss = 0.1
    print("method:", method)
    print("macro_cap:", macro_cap)
    print("n_samples:", n_samples)
    print("ss:", ss)
    main()

# Mean Expected Profit: $3.64 Billion

# Standard Deviation: $69 Million
# (From 100 Monte Carlo simulations)
# Out:
# method: SLSQP
# macro_cap: 0.4
# n_samples: 100
# ss: 0.1
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3640054461.219176
#             Iterations: 636
#             Function evaluations: 288899
#             Gradient evaluations: 632
# Group 0: Surplus = 40860.19, Needed = 30340.49, Gap = -10519.70
# Group 1: Surplus = 14193.65, Needed = 6711.67, Gap = -7481.98
# Group 2: Surplus = 37687.16, Needed = 53355.56, Gap = 15668.40
# Group 3: Surplus = 41706.66, Needed = 6863.42, Gap = -34843.24
# Group 4: Surplus = 10492.92, Needed = 2279.92, Gap = -8213.00
# Group 5: Surplus = 3074.42, Needed = 0.00, Gap = -3074.42
# Group 6: Surplus = 13295.65, Needed = 22007.98, Gap = 8712.33
# Group 7: Surplus = 16497.44, Needed = 5641.90, Gap = -10855.55
# Group 8: Surplus = 32597.61, Needed = 2231.39, Gap = -30366.21
# Group 9: Surplus = 78423.77, Needed = 72482.62, Gap = -5941.16
# Group 10: Surplus = 7075.08, Needed = 4298.70, Gap = -2776.38
# Group 11: Surplus = 11910.60, Needed = 15495.41, Gap = 3584.81
# Group 12: Surplus = 10315.27, Needed = 14400.10, Gap = 4084.83
# Group 13: Surplus = 13581.93, Needed = 13606.79, Gap = 24.86
# Group 14: Surplus = 14592.54, Needed = 16559.85, Gap = 1967.31
# Group 15: Surplus = 12779.97, Needed = 35175.23, Gap = 22395.26
# Group 16: Surplus = 3067.06, Needed = 5588.41, Gap = 2521.35
# Group 17: Surplus = 38296.37, Needed = 17747.29, Gap = -20549.08
# Group 18: Surplus = 92860.43, Needed = 61313.49, Gap = -31546.94
# Group 19: Surplus = 31297.68, Needed = 62354.57, Gap = 31056.90
# Group 20: Surplus = 7024.42, Needed = 17187.62, Gap = 10163.20
# Group 21: Surplus = 131809.73, Needed = 73657.53, Gap = -58152.20
# Group 22: Surplus = 9735.45, Needed = 14031.71, Gap = 4296.26
# Group 23: Surplus = 33560.47, Needed = 22658.50, Gap = -10901.97
# Group 24: Surplus = 2.65, Needed = 576.35, Gap = 573.70
# Group 25: Surplus = 3.33, Needed = 42.44, Gap = 39.11
# Group 26: Surplus = 40539.50, Needed = 57102.80, Gap = 16563.30
# Group 27: Surplus = 32.76, Needed = 0.00, Gap = -32.76
# Group 28: Surplus = 57840.71, Needed = 50136.71, Gap = -7704.00
# Group 29: Surplus = 1891.32, Needed = 8192.97, Gap = 6301.66
# Group 30: Surplus = 14408.37, Needed = 62605.43, Gap = 48197.06
# Group 31: Surplus = 31633.66, Needed = 46223.18, Gap = 14589.52
# Group 32: Surplus = 53610.75, Needed = 57646.41, Gap = 4035.66
# Group 33: Surplus = 584.47, Needed = 1065.11, Gap = 480.64
# Group 34: Surplus = 4816.94, Needed = 2092.00, Gap = -2724.93
# Group 35: Surplus = 34726.85, Needed = 4020.24, Gap = -30706.61
# Group 36: Surplus = 11378.40, Needed = 4553.78, Gap = -6824.62
# Group 37: Surplus = 8447.02, Needed = 1822.66, Gap = -6624.36
# Group 38: Surplus = 404.32, Needed = 50.70, Gap = -353.62
# Group 39: Surplus = 6274.76, Needed = 11606.37, Gap = 5331.61
# Group 40: Surplus = 3.04, Needed = 600.30, Gap = 597.26
# Group 41: Surplus = 80763.22, Needed = 59312.71, Gap = -21450.51
# Group 42: Surplus = 19.49, Needed = 0.00, Gap = -19.49
# Group 43: Surplus = 0.00, Needed = 2491.14, Gap = 2491.14
# Group 44: Surplus = 36283.36, Needed = 8421.07, Gap = -27862.29
# Group 45: Surplus = 105262.89, Needed = 74654.40, Gap = -30608.49
# Group 46: Surplus = 4.42, Needed = 0.00, Gap = -4.42
# Group 47: Surplus = 427.13, Needed = 574.30, Gap = 147.17
# Group 48: Surplus = 22352.54, Needed = 23834.73, Gap = 1482.19
# Group 49: Surplus = 42233.36, Needed = 82576.98, Gap = 40343.62
# Group 50: Surplus = 128338.05, Needed = 66640.34, Gap = -61697.71
# Group 51: Surplus = 12241.15, Needed = 18873.76, Gap = 6632.61
# Group 52: Surplus = 11754.00, Needed = 46713.89, Gap = 34959.89
# Group 53: Surplus = 131762.96, Needed = 115870.18, Gap = -15892.78
# Group 54: Surplus = 8273.96, Needed = 11251.82, Gap = 2977.87
# Group 55: Surplus = 50075.48, Needed = 53272.35, Gap = 3196.88
# Group 56: Surplus = 7081.80, Needed = 33631.56, Gap = 26549.76
# Group 57: Surplus = 67731.69, Needed = 39811.07, Gap = -27920.62
# Group 58: Surplus = 123994.34, Needed = 72635.55, Gap = -51358.79
# Group 59: Surplus = 21241.90, Needed = 22585.05, Gap = 1343.14
# Group 60: Surplus = 22014.47, Needed = 32232.80, Gap = 10218.33
# Group 61: Surplus = 78581.60, Needed = 67828.57, Gap = -10753.03
# Group 62: Surplus = 4382.57, Needed = 19189.50, Gap = 14806.93
# Group 63: Surplus = 22997.44, Needed = 23264.62, Gap = 267.18
# Group 64: Surplus = 13042.51, Needed = 21838.99, Gap = 8796.48
# Group 65: Surplus = 25232.83, Needed = 15441.16, Gap = -9791.67
# Group 66: Surplus = 83597.43, Needed = 25378.90, Gap = -58218.53
# Group 67: Surplus = 1.10, Needed = 31885.36, Gap = 31884.25
# Group 68: Surplus = 7355.29, Needed = 0.00, Gap = -7355.29
# Group 69: Surplus = 0.92, Needed = 10390.57, Gap = 10389.65
# Group 70: Surplus = 4041.30, Needed = 2871.15, Gap = -1170.14
# Group 71: Surplus = 12328.29, Needed = 2392.76, Gap = -9935.53
# Group 72: Surplus = 1.38, Needed = 0.00, Gap = -1.38
# Group 73: Surplus = 23017.73, Needed = 6371.89, Gap = -16645.83
# Group 74: Surplus = 3918.75, Needed = 21160.44, Gap = 17241.69
# Group 75: Surplus = 0.01, Needed = 0.00, Gap = -0.01
# Group 76: Surplus = 3983.85, Needed = 3310.47, Gap = -673.38
# Group 77: Surplus = 18507.51, Needed = 0.00, Gap = -18507.51
# Group 78: Surplus = 15369.52, Needed = 65186.53, Gap = 49817.01
# Group 79: Surplus = 6154.73, Needed = 8403.65, Gap = 2248.91
# Group 80: Surplus = 32803.21, Needed = 50824.22, Gap = 18021.02
# Group 81: Surplus = 6.31, Needed = 1420.20, Gap = 1413.89
# Group 82: Surplus = 128225.13, Needed = 52613.86, Gap = -75611.27
# Group 83: Surplus = 12581.58, Needed = 3750.66, Gap = -8830.92
# Group 84: Surplus = 8458.42, Needed = 104.83, Gap = -8353.58
# Group 85: Surplus = 101176.04, Needed = 39420.57, Gap = -61755.47
# Group 86: Surplus = 33648.97, Needed = 18203.67, Gap = -15445.30
# Group 87: Surplus = 29850.19, Needed = 54364.35, Gap = 24514.16
# Group 88: Surplus = 0.00, Needed = 0.00, Gap = 0.00
# Group 89: Surplus = 77682.96, Needed = 22302.06, Gap = -55380.89
# Group 90: Surplus = 40.69, Needed = 0.00, Gap = -40.69
# Group 91: Surplus = 7912.22, Needed = 35369.19, Gap = 27456.97
# Group 92: Surplus = 311.05, Needed = 3068.71, Gap = 2757.66
# Group 93: Surplus = 52133.66, Needed = 78515.90, Gap = 26382.25
# Group 94: Surplus = 4.28, Needed = 0.00, Gap = -4.28
# Group 95: Surplus = 6.87, Needed = 0.00, Gap = -6.87
# Group 96: Surplus = 10917.82, Needed = 2391.40, Gap = -8526.42
# Group 97: Surplus = 5.95, Needed = 1824.49, Gap = 1818.54
# Group 98: Surplus = 45305.83, Needed = 51399.57, Gap = 6093.74
# Group 99: Surplus = 4908.64, Needed = 1988.76, Gap = -2919.87
# Group 100: Surplus = 37040.23, Needed = 15378.69, Gap = -21661.54
# Group 101: Surplus = 0.79, Needed = 6820.79, Gap = 6820.00
# Group 102: Surplus = 1901.41, Needed = 0.00, Gap = -1901.41
# Group 103: Surplus = 27788.96, Needed = 7547.95, Gap = -20241.00
# Group 104: Surplus = 15258.34, Needed = 7499.35, Gap = -7758.99
# Group 105: Surplus = 0.00, Needed = 0.00, Gap = -0.00
# Group 106: Surplus = 151.74, Needed = 9712.96, Gap = 9561.22
# Group 107: Surplus = 12024.60, Needed = 55339.35, Gap = 43314.75
# Group 108: Surplus = 21229.40, Needed = 10431.58, Gap = -10797.82
# Group 109: Surplus = 1656.81, Needed = 16377.29, Gap = 14720.48
# Group 110: Surplus = 4605.22, Needed = 1732.82, Gap = -2872.40
# Group 111: Surplus = 59803.38, Needed = 47933.52, Gap = -11869.86
# Group 112: Surplus = 5343.03, Needed = 22152.45, Gap = 16809.42
# Group 113: Surplus = 6091.12, Needed = 0.00, Gap = -6091.12
# Group 114: Surplus = 6175.98, Needed = 1223.47, Gap = -4952.51
# Group 115: Surplus = 0.06, Needed = 0.00, Gap = -0.06
# Group 116: Surplus = 11561.46, Needed = 17698.10, Gap = 6136.64
# Group 117: Surplus = 6362.06, Needed = 0.00, Gap = -6362.06
# Group 118: Surplus = 16941.53, Needed = 54818.64, Gap = 37877.11
# Group 119: Surplus = 3.43, Needed = 0.00, Gap = -3.43
# Group 120: Surplus = 8443.09, Needed = 13695.92, Gap = 5252.82
# Group 121: Surplus = 28467.07, Needed = 11634.42, Gap = -16832.65
# Group 122: Surplus = 94286.58, Needed = 62575.01, Gap = -31711.57
# Group 123: Surplus = 21747.12, Needed = 15753.90, Gap = -5993.21
# Group 124: Surplus = 14754.41, Needed = 25008.71, Gap = 10254.30
# Group 125: Surplus = 11476.50, Needed = 27410.11, Gap = 15933.61
# Group 126: Surplus = 7643.45, Needed = 32261.03, Gap = 24617.59
# Group 127: Surplus = 11186.52, Needed = 2876.48, Gap = -8310.04
# Group 128: Surplus = 41988.88, Needed = 100721.70, Gap = 58732.82
# Group 129: Surplus = 6318.52, Needed = 1192.28, Gap = -5126.24
# Group 130: Surplus = 26462.21, Needed = 6952.41, Gap = -19509.80
# Group 131: Surplus = 286.06, Needed = 10105.21, Gap = 9819.15
# Group 132: Surplus = 43951.03, Needed = 9364.53, Gap = -34586.50
# Group 133: Surplus = 71895.57, Needed = 117791.85, Gap = 45896.28
# Group 134: Surplus = 6058.62, Needed = 9633.08, Gap = 3574.46
# Group 135: Surplus = 0.00, Needed = 3926.88, Gap = 3926.88
# Group 136: Surplus = 2779.06, Needed = 3229.94, Gap = 450.88
# Group 137: Surplus = 0.00, Needed = 0.00, Gap = -0.00
# Group 138: Surplus = 9376.00, Needed = 18615.56, Gap = 9239.55
# Group 139: Surplus = 1099.87, Needed = 0.00, Gap = -1099.87
# Group 140: Surplus = 12568.20, Needed = 143.16, Gap = -12425.04
# Group 141: Surplus = 10299.17, Needed = 31820.45, Gap = 21521.29
# Group 142: Surplus = 11788.35, Needed = 56498.45, Gap = 44710.10
# Group 143: Surplus = 1.34, Needed = 19988.38, Gap = 19987.04
# Group 144: Surplus = 40548.18, Needed = 28711.63, Gap = -11836.55
# Group 145: Surplus = 87466.53, Needed = 61092.34, Gap = -26374.19
# Group 146: Surplus = 81693.98, Needed = 78896.19, Gap = -2797.80
# Group 147: Surplus = 15957.49, Needed = 70155.71, Gap = 54198.22
# Group 148: Surplus = 4182.75, Needed = 17476.67, Gap = 13293.92
# Group 149: Surplus = 7099.80, Needed = 3878.09, Gap = -3221.71
# Group 150: Surplus = 857.33, Needed = 3460.42, Gap = 2603.09
# Group 151: Surplus = 2045.77, Needed = 4016.74, Gap = 1970.97
# Group 152: Surplus = 240119.94, Needed = 295749.17, Gap = 55629.23
# Group 153: Surplus = 39.02, Needed = 0.00, Gap = -39.02
# Group 154: Surplus = 2961.83, Needed = 19512.04, Gap = 16550.21
# Group 155: Surplus = 18374.20, Needed = 24536.14, Gap = 6161.94
# Group 156: Surplus = 4024.95, Needed = 9952.54, Gap = 5927.59
# Group 157: Surplus = 67082.61, Needed = 54078.85, Gap = -13003.76
# Group 158: Surplus = 11169.90, Needed = 1439.85, Gap = -9730.05
# Group 159: Surplus = 95476.73, Needed = 147455.77, Gap = 51979.03
# Group 160: Surplus = 33172.27, Needed = 19174.80, Gap = -13997.47
# Group 161: Surplus = 31442.98, Needed = 0.00, Gap = -31442.98
# Group 162: Surplus = 15517.71, Needed = 30850.27, Gap = 15332.56
# Group 163: Surplus = 7458.36, Needed = 8263.45, Gap = 805.09
# Group 164: Surplus = 22680.67, Needed = 9493.65, Gap = -13187.01
# Group 165: Surplus = 7086.79, Needed = 69423.14, Gap = 62336.34
# Group 166: Surplus = 14088.29, Needed = 5279.52, Gap = -8808.77
# Group 167: Surplus = 25163.23, Needed = 75378.83, Gap = 50215.60
# Group 168: Surplus = 48902.55, Needed = 29974.77, Gap = -18927.78
# Group 169: Surplus = 10449.50, Needed = 5682.39, Gap = -4767.10
# Group 170: Surplus = 66678.41, Needed = 45334.84, Gap = -21343.57
# Group 171: Surplus = 7199.76, Needed = 2840.12, Gap = -4359.64
# Group 172: Surplus = 15283.19, Needed = 58065.09, Gap = 42781.90
# Group 173: Surplus = 6767.70, Needed = 35340.33, Gap = 28572.63
# Group 174: Surplus = 18602.52, Needed = 17692.02, Gap = -910.49
# Group 175: Surplus = 0.00, Needed = 20110.94, Gap = 20110.94
# Group 176: Surplus = 14046.55, Needed = 41258.74, Gap = 27212.18
# Group 177: Surplus = 17768.56, Needed = 15333.75, Gap = -2434.80
# Group 178: Surplus = 1825.20, Needed = 0.00, Gap = -1825.20
# Group 179: Surplus = 128695.96, Needed = 74347.09, Gap = -54348.87
# Group 180: Surplus = 22.30, Needed = 923.58, Gap = 901.27
# Group 181: Surplus = 15116.68, Needed = 504.25, Gap = -14612.43
# Group 182: Surplus = 92533.99, Needed = 61521.36, Gap = -31012.63
# Group 183: Surplus = 0.00, Needed = 3250.83, Gap = 3250.83
# Group 184: Surplus = 9731.70, Needed = 0.00, Gap = -9731.70
# Group 185: Surplus = 27462.80, Needed = 61488.65, Gap = 34025.84
# Group 186: Surplus = 0.00, Needed = 0.00, Gap = -0.00
# Group 187: Surplus = 0.42, Needed = 0.00, Gap = -0.42
# Group 188: Surplus = 6634.05, Needed = 11293.19, Gap = 4659.14
# Group 189: Surplus = 0.00, Needed = 0.00, Gap = 0.00
# Group 190: Surplus = 10711.96, Needed = 7916.81, Gap = -2795.15
# Group 191: Surplus = 9912.08, Needed = 6351.19, Gap = -3560.89
# Group 192: Surplus = 3032.20, Needed = 1889.63, Gap = -1142.57
# Group 193: Surplus = 6695.33, Needed = 9327.70, Gap = 2632.37
# Group 194: Surplus = 10321.34, Needed = 5354.81, Gap = -4966.53
# Group 195: Surplus = 50379.03, Needed = 47145.34, Gap = -3233.69
# Group 196: Surplus = 29974.97, Needed = 65731.76, Gap = 35756.79
# Group 197: Surplus = 40013.06, Needed = 12570.71, Gap = -27442.35
#
# Optimization finished: Success
# Message: Optimization terminated successfully
#
# Mean Profit: 3640054461.219176
# Std Dev Profit: 69021454.91625635
# Saved all outputs to: SLSQP_SoftConstraints_gc0.1
